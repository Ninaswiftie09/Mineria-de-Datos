# %%
import os
import pandas as pd
import pyreadstat
import matplotlib.pyplot as plt
from matplotlib.pylab import chisquare

# %%
ruta_carpeta = "data"
ruta_salida = "base_final_unificada_normalizada.sav"

# %%
archivos_sav = [f for f in os.listdir(ruta_carpeta) if f.endswith(".sav")]

print(f"Archivos encontrados: {len(archivos_sav)}")
archivos_sav
# Out:
# Archivos encontrados: 11
# ['201712041525490jPevoWKMXOZPJq5KpYU9Tlj4peGmEEd.sav',
#  '20181226143330lNO5qooyMLWxGu8XJLL7BXprdvTjfO0q.sav',
#  '20191129151703IbgVgHc5enyxiXopUTuxcrUzC5WPkzCr.sav',
#  '20201201154915Yd6FWtyVWNULqHYzwTiXcRaLAl8B8jul.sav',
#  '20210730184315Yd6FWtyVWNULqHYzwTiXcRaLAl8B8jul (2).sav',
#  '20220729171254FYBQhYtMxyPU3C9wbQbaxGTEtg107w32.sav',
#  '202307282030176jUXYrCteX8JWZUbSn6B6fCXUXaZQ78F.sav',
#  '2W4N7bnfbaVntLsINTDXCUZ57oCLyC3o.sav',
#  'PZrZNHRSBszrytG8VuGha9WbabSmldOl.sav',
#  'RceAnfmGqPRS02bqMI8XMzt6ZXx64XS7.sav',
#  'RESsr1X3WuQcTxhLVlyslBKGtHAXqSrH.sav']

# %%
lista_bases = []
resumen = []

for archivo in archivos_sav:
    try:
        ruta_archivo = os.path.join(ruta_carpeta, archivo)
        df = pd.read_spss(ruta_archivo)

        columnas_originales = set(df.columns)

        # Normalizar nombres equivalentes
        if "PPERHOM" in df.columns:
            df = df.rename(columns={"PPERHOM": "PUEHOM"})
        if "PPERMUJ" in df.columns:
            df = df.rename(columns={"PPERMUJ": "PUEMUJ"})

        columnas_finales = set(df.columns)

        resumen.append({
            "archivo": archivo,
            "columnas_antes": len(columnas_originales),
            "columnas_despues": len(columnas_finales),
            "renombro_PPER": columnas_originales != columnas_finales
        })

        lista_bases.append(df)

        print(f"Procesado: {archivo}")

    except Exception as e:
        print(f"ERROR con {archivo}: {e}")
# Out:
# Procesado: 201712041525490jPevoWKMXOZPJq5KpYU9Tlj4peGmEEd.sav
# Procesado: 20181226143330lNO5qooyMLWxGu8XJLL7BXprdvTjfO0q.sav
# Procesado: 20191129151703IbgVgHc5enyxiXopUTuxcrUzC5WPkzCr.sav
# Procesado: 20201201154915Yd6FWtyVWNULqHYzwTiXcRaLAl8B8jul.sav
# Procesado: 20210730184315Yd6FWtyVWNULqHYzwTiXcRaLAl8B8jul (2).sav
# Procesado: 20220729171254FYBQhYtMxyPU3C9wbQbaxGTEtg107w32.sav
# Procesado: 202307282030176jUXYrCteX8JWZUbSn6B6fCXUXaZQ78F.sav
# Procesado: 2W4N7bnfbaVntLsINTDXCUZ57oCLyC3o.sav
# Procesado: PZrZNHRSBszrytG8VuGha9WbabSmldOl.sav
# Procesado: RceAnfmGqPRS02bqMI8XMzt6ZXx64XS7.sav
# Procesado: RESsr1X3WuQcTxhLVlyslBKGtHAXqSrH.sav

# %%
base_final = pd.concat(lista_bases, ignore_index=True)

print(f"Base final creada con {base_final.shape[0]} filas y {base_final.shape[1]} columnas")
# Out:
# Base final creada con 71576 filas y 23 columnas

# %%
pyreadstat.write_sav(base_final, ruta_salida)

print(f" Archivo exportado correctamente: {ruta_salida}")
# Out:
#  Archivo exportado correctamente: base_final_unificada_normalizada.sav

# %%
import numpy as np
import pandas as pd

ruta_archivo = "base_final_unificada_normalizada.sav"

df, meta = pyreadstat.read_sav(ruta_archivo)

num_reales = ["EDADHOM", "EDADMUJ", "DIAOCU"]
for c in num_reales:
    df[c] = pd.to_numeric(df[c], errors="coerce")

df.loc[df["EDADHOM"] >= 120, "EDADHOM"] = np.nan
df.loc[df["EDADMUJ"] >= 120, "EDADMUJ"] = np.nan
df.loc[(df["DIAOCU"] < 1) | (df["DIAOCU"] > 31), "DIAOCU"] = np.nan

df_num = df[num_reales].copy()

print("df shape:", df.shape)
print("df_num shape:", df_num.shape)
# Out:
# df shape: (71576, 23)
# df_num shape: (71576, 3)

# %%
#Descripción General del conjunto de datos 
num_observaciones = df.shape[0]
num_variables = df.shape[1]

print("Cantidad de observaciones:", num_observaciones)
print("Cantidad de variables:", num_variables)
# Out:
# Cantidad de observaciones: 71576
# Cantidad de variables: 23

# %%
# Significado y tipo de cada variable 

diccionario = pd.DataFrame({
    "Variable": df.columns,
    "Tipo_dato": [str(df[c].dtype) for c in df.columns],
    "Tipo_variable": ["Categórica"] * len(df.columns)
})

numericas = ["EDADHOM", "EDADMUJ", "DIAOCU"]
diccionario.loc[diccionario["Variable"].isin(numericas), "Tipo_variable"] = "Numérica"

diccionario
# Out:
#    Variable Tipo_dato Tipo_variable
# 0    DEPREG    object    Categórica
# 1    MUPREG    object    Categórica
# 2    MESREG    object    Categórica
# 3    AÑOREG   float64    Categórica
# 4    DIAOCU   float64      Numérica
# 5    MESOCU    object    Categórica
# 6    AÑOOCU   float64    Categórica
# 7    DEPOCU    object    Categórica
# 8    MUPOCU    object    Categórica
# 9   EDADHOM   float64      Numérica
# 10  EDADMUJ   float64      Numérica
# 11   PUEHOM    object    Categórica
# 12   PUEMUJ    object    Categórica
# 13   NACHOM    object    Categórica
# 14   NACMUJ    object    Categórica
# 15   ESCHOM    object    Categórica
# 16   ESCMUJ    object    Categórica
# 17  CIUOHOM    object    Categórica
# 18  CIUOMUJ    object    Categórica
# 19   GETHOM    object    Categórica
# 20   GETMUJ    object    Categórica
# 21   OCUHOM    object    Categórica
# 22   OCUMUJ    object    Categórica

# %%
#Exploración de variables numéricas - tendencia central
tendencia_central = pd.DataFrame({
    "media": df_num.mean(numeric_only=True),
    "mediana": df_num.median(numeric_only=True),
    "moda": df_num.mode(numeric_only=True).iloc[0]
})

tendencia_central
# Out:
#              media  mediana  moda
# EDADHOM  36.024360     34.0  31.0
# EDADMUJ  32.802849     31.0  27.0
# DIAOCU   15.733584     16.0  22.0

# %%
#Distribución y medidas de dispersión
distribucion = pd.DataFrame({
    "min": df_num.min(numeric_only=True),
    "max": df_num.max(numeric_only=True),
    "rango": df_num.max(numeric_only=True) - df_num.min(numeric_only=True),
    "varianza": df_num.var(numeric_only=True),
    "desviacion_std": df_num.std(numeric_only=True),
    "coef_variacion": df_num.std(numeric_only=True) / df_num.mean(numeric_only=True)
})

orden = df_num.quantile([0.25, 0.5, 0.75]).T
orden.columns = ["Q1_25%", "Q2_50%_mediana", "Q3_75%"]

forma = pd.DataFrame({
    "skewness": df_num.skew(numeric_only=True),
    "kurtosis": df_num.kurtosis(numeric_only=True)
})

distribucion, orden, forma
# Out:
# (          min   max  rango    varianza  desviacion_std  coef_variacion
#  EDADHOM  15.0  98.0   83.0  100.558787       10.027900        0.278364
#  EDADMUJ  15.0  81.0   66.0   83.123230        9.117194        0.277939
#  DIAOCU    1.0  31.0   30.0   75.399772        8.683304        0.551896,
#           Q1_25%  Q2_50%_mediana  Q3_75%
#  EDADHOM    29.0            34.0    41.0
#  EDADMUJ    26.0            31.0    38.0
#  DIAOCU      8.0            16.0    23.0,
#           skewness  kurtosis
#  EDADHOM  1.168343  1.660497
#  EDADMUJ  1.045180  1.272305
#  DIAOCU   0.007677 -1.189502)

# %%
def tabla_freq(col, top=10):
    t = df[col].value_counts(dropna=False).head(top).to_frame("frecuencia")
    t["porcentaje"] = (t["frecuencia"] / len(df) * 100).round(2)
    return t

freq_DEPREG = tabla_freq("DEPREG", top=10)
freq_DEPOCU = tabla_freq("DEPOCU", top=10)
freq_MESOCU = tabla_freq("MESOCU", top=12)
freq_ESCHOM = tabla_freq("ESCHOM", top=10)
freq_ESCMUJ = tabla_freq("ESCMUJ", top=10)

freq_DEPREG, freq_DEPOCU, freq_MESOCU, freq_ESCHOM, freq_ESCMUJ
# Out:
# (                frecuencia  porcentaje
#  DEPREG
#  Guatemala            27573       38.52
#  Quetzaltenango        5771        8.06
#  Escuintla             3187        4.45
#  San Marcos            2766        3.86
#  Jutiapa               2629        3.67
#  Huehuetenango         2381        3.33
#  Izabal                2255        3.15
#  Retalhuleu            2116        2.96
#  Santa Rosa            1981        2.77
#  Suchitepequez         1926        2.69,
#                  frecuencia  porcentaje
#  DEPOCU
#  Guatemala            26530       37.07
#  Quetzaltenango        5437        7.60
#  Escuintla             3481        4.86
#  Jutiapa               3064        4.28
#  San Marcos            3041        4.25
#  Huehuetenango         2480        3.46
#  Izabal                2313        3.23
#  Suchitepequez         2108        2.95
#  Retalhuleu            2072        2.89
#  Santa Rosa            2051        2.87,
#              frecuencia  porcentaje
#  MESOCU
# ...

# %%
# 1) Correlación EDADHOM vs EDADMUJ
corr_edades = df_num[["EDADHOM","EDADMUJ"]].corr()

# 2) Diferencia de edades
df["DIF_EDAD"] = df["EDADHOM"] - df["EDADMUJ"]
res_dif = df["DIF_EDAD"].describe()

# 3) Divorcios por mes de ocurrencia (frecuencia)
divorcios_por_mes = df["MESOCU"].value_counts().sort_index().to_frame("frecuencia")
divorcios_por_mes["porcentaje"] = (divorcios_por_mes["frecuencia"] / len(df) * 100).round(2)

corr_edades, res_dif, divorcios_por_mes
# Out:
# (          EDADHOM   EDADMUJ
#  EDADHOM  1.000000  0.792371
#  EDADMUJ  0.792371  1.000000,
#  count    34359.000000
#  mean         3.162810
#  std          6.062616
#  min        -41.000000
#  25%          0.000000
#  50%          2.000000
#  75%          6.000000
#  max         75.000000
#  Name: DIF_EDAD, dtype: float64,
#              frecuencia  porcentaje
#  MESOCU
#  Abril             5720        7.99
#  Agosto            6620        9.25
#  Diciembre         3854        5.38
#  Enero             5351        7.48
#  Febrero           6378        8.91
#  Julio             6389        8.93
#  Junio             6119        8.55
#  Marzo             6989        9.76
#  Mayo              6269        8.76
#  Noviembre         4883        6.82
#  Octubre           7003        9.78
#  Septiembre        6001        8.38)

# %%
# PASO 2: ANÁLISIS GEOGRÁFICO 

# Crear variables de región (agrupación de departamentos)
region_map = {
    'Guatemala': 'Metropolitana',
    'Sacatepéquez': 'Central',
    'Chimaltenango': 'Central',
    'El Progreso': 'Nororiental',
    'Izabal': 'Nororiental',
    'Zacapa': 'Nororiental',
    'Chiquimula': 'Nororiental',
    'Jalapa': 'Nororiental',
    'Jutiapa': 'Nororiental',
    'Santa Rosa': 'Nororiental',
    'Alta Verapaz': 'Norte',
    'Baja Verapaz': 'Norte',
    'Petén': 'Norte',
    'Huehuetenango': 'Noroccidental',
    'Quiché': 'Noroccidental',
    'Quetzaltenango': 'Suroccidental',
    'San Marcos': 'Suroccidental',
    'Totonicapán': 'Suroccidental',
    'Sololá': 'Suroccidental',
    'Suchitepéquez': 'Suroccidental',
    'Retalhuleu': 'Suroccidental',
    'Escuintla': 'Central'
}

# Aplicar el mapeo
df['REGION_REG'] = df['DEPREG'].map(region_map)
df['REGION_OCU'] = df['DEPOCU'].map(region_map)

# Verificar que se crearon correctamente
print("Distribución por región de REGISTRO:")
print(df['REGION_REG'].value_counts(dropna=False))
print("\nDistribución por región de OCURRENCIA:")
print(df['REGION_OCU'].value_counts(dropna=False))

# Comparar distribución por región (porcentajes)
region_reg = df['REGION_REG'].value_counts(normalize=True).mul(100).round(2)
region_ocu = df['REGION_OCU'].value_counts(normalize=True).mul(100).round(2)

print("\n=== DISTRIBUCIÓN POR REGIÓN (PORCENTAJES) ===")
print("\nRegión de REGISTRO:")
print(region_reg)
print("\nRegión de OCURRENCIA:")
print(region_ocu)

# ¿Qué porcentaje se divorcia en el mismo departamento donde registra?
mismo_dep = (df['DEPREG'] == df['DEPOCU']).mean() * 100
print(f"\nPorcentaje que se divorcia en el mismo departamento donde registra: {mismo_dep:.2f}%")

# Cruzar departamento de registro vs ocurrencia (para los principales)
top_deps = df['DEPREG'].value_counts().head(5).index
contingencia_dep = pd.crosstab(df['DEPREG'], df['DEPOCU'], normalize='index').mul(100).round(2)
print("\nMatriz de contingencia (porcentaje por fila - Departamento de REGISTRO):")
print(contingencia_dep.loc[top_deps, top_deps])
# Out:
# Distribución por región de REGISTRO:
# REGION_REG
# Metropolitana    27573
# Nororiental      13569
# Suroccidental    11789
# NaN               6766
# Central           5287
# Norte             3515
# Noroccidental     3077
# Name: count, dtype: int64
#
# Distribución por región de OCURRENCIA:
# REGION_OCU
# Metropolitana    26530
# Nororiental      13935
# Suroccidental    11779
# NaN               7002
# Central           5471
# Norte             3638
# Noroccidental     3221
# Name: count, dtype: int64
#
# === DISTRIBUCIÓN POR REGIÓN (PORCENTAJES) ===
#
# Región de REGISTRO:
# REGION_REG
# Metropolitana    42.54
# Nororiental      20.94
# Suroccidental    18.19
# Central           8.16
# Norte             5.42
# Noroccidental     4.75
# Name: proportion, dtype: float64
#
# Región de OCURRENCIA:
# REGION_OCU
# Metropolitana    41.08
# Nororiental      21.58
# Suroccidental    18.24
# Central           8.47
# Norte             5.63
# Noroccidental     4.99
# ...

# %%
# PASO 3: VISUALIZACION GEOGRAFICA


# Gráfico de barras: comparación regiones
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
region_reg.sort_values().plot(kind='barh', color='skyblue')
plt.xlabel('Porcentaje')
plt.title('Distribución por Región - REGISTRO')

plt.subplot(1, 2, 2)
region_ocu.sort_values().plot(kind='barh', color='lightcoral')
plt.xlabel('Porcentaje')
plt.title('Distribución por Región - OCURRENCIA')

plt.tight_layout()
plt.show()

# %%
# PASO 4: ANALISIS DE MOVILIDAD GEOGRAFICA

# Crear columna que indique si cambió de departamento
df['CAMBIO_DEP'] = df['DEPREG'] != df['DEPOCU']
porcentaje_cambio = df['CAMBIO_DEP'].mean() * 100
print(f"Porcentaje que cambio de departamento entre ocurrencia y registro: {porcentaje_cambio:.2f}%")

# De donde vienen los que se divorcian en Guatemala
vienen_a_guate = df[df['DEPOCU'] == 'Guatemala']['DEPREG'].value_counts()
print("\nPersonas que se divorcian en Guatemala, de donde vienen")
print(vienen_a_guate.head(10))
# Out:
# Porcentaje que cambio de departamento entre ocurrencia y registro: 14.64%
#
# Personas que se divorcian en Guatemala, de donde vienen
# DEPREG
# Guatemala         23897
# Escuintla           247
# Sacatepequez        241
# Santa Rosa          223
# Chimaltenango       210
# Sacatepéquez        190
# Quetzaltenango      176
# Jutiapa             144
# Jalapa              136
# El Progreso         119
# Name: count, dtype: int64

# %%
# ============================================
# PASO 5: ANÁLISIS TEMPORAL DETALLADO
# ============================================

print("="*60)
print("ANÁLISIS TEMPORAL DE DIVORCIOS")
print("="*60)

# 5.1 Preparación de variables temporales
# ----------------------------------------

# Crear variable de mes ordenado correctamente
meses_orden = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
               'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
df['MESOCU'] = pd.Categorical(df['MESOCU'], categories=meses_orden, ordered=True)

# Crear variable de fecha completa para análisis de series temporales
df['FECHA_OCU'] = pd.to_datetime(df['AÑOOCU'].astype(str) + '-' + 
                                   df['MESOCU'].astype(str) + '-01', errors='coerce')

# 5.2 Tendencia anual
# -------------------
print("\n--- TENDENCIA ANUAL ---")
tendencia_anual = df['AÑOOCU'].value_counts().sort_index()
print("Divorcios por año:")
for año, count in tendencia_anual.items():
    print(f"  {int(año)}: {count} divorcios")

# Calcular variación interanual
años_ordenados = sorted(tendencia_anual.index)
print("\nVariación interanual:")
for i in range(1, len(años_ordenados)):
    año_actual = años_ordenados[i]
    año_anterior = años_ordenados[i-1]
    variacion = ((tendencia_anual[año_actual] - tendencia_anual[año_anterior]) / tendencia_anual[año_anterior]) * 100
    print(f"  {int(año_anterior)} → {int(año_actual)}: {variacion:.1f}%")

# 5.3 Estacionalidad mensual
# ---------------------------
print("\n--- ESTACIONALIDAD MENSUAL ---")
estacionalidad = df['MESOCU'].value_counts().sort_index()
print("Distribución por mes:")
for mes, count in estacionalidad.items():
    porcentaje = (count / len(df)) * 100
    print(f"  {mes}: {count} divorcios ({porcentaje:.2f}%)")

# Prueba chi-cuadrado para uniformidad de meses
frecuencias_observadas = estacionalidad.values
frecuencias_esperadas = [len(df)/12] * 12
chi2_meses, p_valor_meses = chisquare(frecuencias_observadas, frecuencias_esperadas)
print(f"\nPrueba de uniformidad mensual:")
print(f"  Chi-cuadrado: {chi2_meses:.2f}")
print(f"  Valor p: {p_valor_meses:.10f}")
print(f"  Conclusión: {'No hay' if p_valor_meses > 0.05 else 'Sí hay'} estacionalidad significativa")

# 5.4 Análisis por día del mes
# -----------------------------
print("\n--- ANÁLISIS POR DÍA DEL MES ---")
dias_sin_nan = df['DIAOCU'].dropna()
dias_stats = dias_sin_nan.describe()
print("Estadísticas del día de ocurrencia:")
print(f"  Media: {dias_stats['mean']:.2f}")
print(f"  Mediana: {dias_stats['50%']:.0f}")
print(f"  Moda: {dias_sin_nan.mode()[0]:.0f}")
print(f"  Desviación estándar: {dias_stats['std']:.2f}")

# Días con más divorcios
top_dias = dias_sin_nan.value_counts().head(5)
print("\nDías con más divorcios:")
for dia, count in top_dias.items():
    print(f"  Día {int(dia)}: {count} divorcios ({count/len(df)*100:.2f}%)")

# 5.5 Visualizaciones temporales
# -------------------------------
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Gráfico 1: Tendencia anual
axes[0,0].plot(tendencia_anual.index.astype(int), tendencia_anual.values, marker='o', linestyle='-', color='blue')
axes[0,0].set_xlabel('Año')
axes[0,0].set_ylabel('Número de Divorcios')
axes[0,0].set_title('Tendencia Anual de Divorcios')
axes[0,0].grid(True, alpha=0.3)

# Gráfico 2: Estacionalidad mensual
bars = axes[0,1].bar(estacionalidad.index, estacionalidad.values, color='skyblue')
axes[0,1].set_xlabel('Mes')
axes[0,1].set_ylabel('Número de Divorcios')
axes[0,1].set_title('Distribución Mensual de Divorcios')
axes[0,1].tick_params(axis='x', rotation=45)
# Resaltar diciembre
bars[-1].set_color('red')

# Gráfico 3: Distribución por día
dias_counts = dias_sin_nan.value_counts().sort_index()
axes[1,0].bar(dias_counts.index, dias_counts.values, color='lightgreen')
axes[1,0].set_xlabel('Día del Mes')
axes[1,0].set_ylabel('Número de Divorcios')
axes[1,0].set_title('Distribución por Día del Mes')
axes[1,0].set_xticks(range(1, 32, 2))

# Gráfico 4: Heatmap mes vs día (opcional, si tenemos suficientes datos)
try:
    df['DIAOCU_int'] = df['DIAOCU'].fillna(0).astype(int)
    pivot = pd.crosstab(df['MESOCU'], df['DIAOCU_int'])
    sns.heatmap(pivot, ax=axes[1,1], cmap='YlOrRd', cbar_kws={'label': 'Frecuencia'})
    axes[1,1].set_title('Distribución Mes vs Día')
    axes[1,1].set_xlabel('Día')
    axes[1,1].set_ylabel('Mes')
except:
    axes[1,1].text(0.5, 0.5, 'Datos insuficientes\npara heatmap', 
                   ha='center', va='center', fontsize=12)
    axes[1,1].set_title('Mes vs Día (no disponible)')

plt.tight_layout()
plt.show()
# Out:
# ...
# ANÁLISIS TEMPORAL DE DIVORCIOS
# ...
#
# --- TENDENCIA ANUAL ---
# Divorcios por año:
#   2015: 5726 divorcios
#   2016: 5665 divorcios
#   2017: 5808 divorcios
#   2018: 6255 divorcios
#   2019: 8203 divorcios
#   2020: 4074 divorcios
#   2021: 9621 divorcios
#   2022: 9950 divorcios
#
# Variación interanual:
#   2015 → 2016: -1.1%
#   2016 → 2017: 2.5%
#   2017 → 2018: 7.7%
#   2018 → 2019: 31.1%
#   2019 → 2020: -50.3%
#   2020 → 2021: 136.2%
#   2021 → 2022: 3.4%
#
# --- ESTACIONALIDAD MENSUAL ---
# Distribución por mes:
#   Enero: 5351 divorcios (7.48%)
#   Febrero: 6378 divorcios (8.91%)
#   Marzo: 6989 divorcios (9.76%)
#   Abril: 5720 divorcios (7.99%)
#   Mayo: 6269 divorcios (8.76%)
#   Junio: 6119 divorcios (8.55%)
#   Julio: 6389 divorcios (8.93%)
#   Agosto: 6620 divorcios (9.25%)
#   Septiembre: 6001 divorcios (8.38%)
#   Octubre: 7003 divorcios (9.78%)
#   Noviembre: 4883 divorcios (6.82%)
#   Diciembre: 3854 divorcios (5.38%)
# ...

# %%
# ============================================
# PASO 6: ANÁLISIS DEMOGRÁFICO DE HOMBRES
# ============================================

print("\n" + "="*60)
print("ANÁLISIS DEMOGRÁFICO - HOMBRES")
print("="*60)

# 6.1 Distribución de edades
# ---------------------------
print("\n--- DISTRIBUCIÓN DE EDAD (HOMBRES) ---")
edad_hom_stats = df['EDADHOM'].describe()
print(f"Estadísticas de edad de hombres al divorcio:")
print(f"  Media: {edad_hom_stats['mean']:.2f} años")
print(f"  Mediana: {edad_hom_stats['50%']:.2f} años")
print(f"  Mínimo: {edad_hom_stats['min']:.0f} años")
print(f"  Máximo: {edad_hom_stats['max']:.0f} años")
print(f"  Rango: {edad_hom_stats['max'] - edad_hom_stats['min']:.0f} años")

# Rangos etarios para hombres
bins_h = [0, 20, 30, 40, 50, 60, 100]
labels_h = ['<20', '20-29', '30-39', '40-49', '50-59', '60+']
df['RANGO_EDAD_HOM'] = pd.cut(df['EDADHOM'], bins=bins_h, labels=labels_h, right=False)
rango_hombres = df['RANGO_EDAD_HOM'].value_counts().sort_index()
print("\nDistribución por rango etario:")
for rango, count in rango_hombres.items():
    porcentaje = (count / rango_hombres.sum()) * 100
    print(f"  {rango}: {count} ({porcentaje:.1f}%)")

# 6.2 Pueblo de pertenencia
# --------------------------
print("\n--- PUEBLO DE PERTENENCIA (HOMBRES) ---")
pueblo_hom = df['PUEHOM'].value_counts().head(8)
print("Principales pueblos de pertenencia:")
for pueblo, count in pueblo_hom.items():
    porcentaje = (count / len(df)) * 100
    print(f"  {pueblo}: {count} ({porcentaje:.2f}%)")

# 6.3 Nacionalidad
# -----------------
print("\n--- NACIONALIDAD (HOMBRES) ---")
nacionalidad_hom = df['NACHOM'].value_counts().head(5)
print("Principales nacionalidades:")
for nac, count in nacionalidad_hom.items():
    porcentaje = (count / len(df)) * 100
    print(f"  {nac}: {count} ({porcentaje:.2f}%)")

# 6.4 Escolaridad (ya la vimos, pero profundizamos)
# -----------------
print("\n--- ESCOLARIDAD (HOMBRES) ---")
escolaridad_hom = df['ESCHOM'].value_counts().head(8)
print("Distribución de escolaridad:")
for esc, count in escolaridad_hom.items():
    porcentaje = (count / len(df)) * 100
    print(f"  {esc}: {count} ({porcentaje:.2f}%)")
# Out:
# ...
# ANÁLISIS DEMOGRÁFICO - HOMBRES
# ...
#
# --- DISTRIBUCIÓN DE EDAD (HOMBRES) ---
# Estadísticas de edad de hombres al divorcio:
#   Media: 36.02 años
#   Mediana: 34.00 años
#   Mínimo: 15 años
#   Máximo: 98 años
#   Rango: 83 años
#
# Distribución por rango etario:
#   <20: 75 (0.2%)
#   20-29: 10349 (28.1%)
#   30-39: 15577 (42.4%)
#   40-49: 6975 (19.0%)
#   50-59: 2611 (7.1%)
#   60+: 1194 (3.2%)
#
# --- PUEBLO DE PERTENENCIA (HOMBRES) ---
# Principales pueblos de pertenencia:
#   Ignorado: 33898 (47.36%)
#   Ladino / Mestizo: 14745 (20.60%)
#   : 5157 (7.20%)
#   Mestizo / ladino: 5152 (7.20%)
#   Maya: 5044 (7.05%)
#   Mestizo, Ladino: 4994 (6.98%)
#   Mestizo / Ladino: 2042 (2.85%)
#   Otro: 513 (0.72%)
#
# --- NACIONALIDAD (HOMBRES) ---
# Principales nacionalidades:
#   Guatemala: 70177 (98.05%)
#   Ignorado: 272 (0.38%)
#   Estados Unidos de América: 235 (0.33%)
#   El Salvador: 158 (0.22%)
#   México: 96 (0.13%)
#
# --- ESCOLARIDAD (HOMBRES) ---
# Distribución de escolaridad:
# ...

# %%
# ============================================
# PASO 7: ANÁLISIS DEMOGRÁFICO DE MUJERES
# ============================================

print("\n" + "="*60)
print("ANÁLISIS DEMOGRÁFICO - MUJERES")
print("="*60)

# 7.1 Distribución de edades
# ---------------------------
print("\n--- DISTRIBUCIÓN DE EDAD (MUJERES) ---")
edad_muj_stats = df['EDADMUJ'].describe()
print(f"Estadísticas de edad de mujeres al divorcio:")
print(f"  Media: {edad_muj_stats['mean']:.2f} años")
print(f"  Mediana: {edad_muj_stats['50%']:.2f} años")
print(f"  Mínimo: {edad_muj_stats['min']:.0f} años")
print(f"  Máximo: {edad_muj_stats['max']:.0f} años")
print(f"  Rango: {edad_muj_stats['max'] - edad_muj_stats['min']:.0f} años")

# Rangos etarios para mujeres
bins_m = [0, 20, 30, 40, 50, 60, 100]
labels_m = ['<20', '20-29', '30-39', '40-49', '50-59', '60+']
df['RANGO_EDAD_MUJ'] = pd.cut(df['EDADMUJ'], bins=bins_m, labels=labels_m, right=False)
rango_mujeres = df['RANGO_EDAD_MUJ'].value_counts().sort_index()
print("\nDistribución por rango etario:")
for rango, count in rango_mujeres.items():
    porcentaje = (count / rango_mujeres.sum()) * 100
    print(f"  {rango}: {count} ({porcentaje:.1f}%)")

# 7.2 Pueblo de pertenencia
# --------------------------
print("\n--- PUEBLO DE PERTENENCIA (MUJERES) ---")
pueblo_muj = df['PUEMUJ'].value_counts().head(8)
print("Principales pueblos de pertenencia:")
for pueblo, count in pueblo_muj.items():
    porcentaje = (count / len(df)) * 100
    print(f"  {pueblo}: {count} ({porcentaje:.2f}%)")

# 7.3 Nacionalidad
# -----------------
print("\n--- NACIONALIDAD (MUJERES) ---")
nacionalidad_muj = df['NACMUJ'].value_counts().head(5)
print("Principales nacionalidades:")
for nac, count in nacionalidad_muj.items():
    porcentaje = (count / len(df)) * 100
    print(f"  {nac}: {count} ({porcentaje:.2f}%)")

# 7.4 Escolaridad
# -----------------
print("\n--- ESCOLARIDAD (MUJERES) ---")
escolaridad_muj = df['ESCMUJ'].value_counts().head(8)
print("Distribución de escolaridad:")
for esc, count in escolaridad_muj.items():
    porcentaje = (count / len(df)) * 100
    print(f"  {esc}: {count} ({porcentaje:.2f}%)")
# Out:
# ...
# ANÁLISIS DEMOGRÁFICO - MUJERES
# ...
#
# --- DISTRIBUCIÓN DE EDAD (MUJERES) ---
# Estadísticas de edad de mujeres al divorcio:
#   Media: 32.80 años
#   Mediana: 31.00 años
#   Mínimo: 15 años
#   Máximo: 81 años
#   Rango: 66 años
#
# Distribución por rango etario:
#   <20: 659 (1.8%)
#   20-29: 14973 (40.6%)
#   30-39: 13726 (37.2%)
#   40-49: 5380 (14.6%)
#   50-59: 1655 (4.5%)
#   60+: 462 (1.3%)
#
# --- PUEBLO DE PERTENENCIA (MUJERES) ---
# Principales pueblos de pertenencia:
#   Ignorado: 33977 (47.47%)
#   Ladino / Mestizo: 12676 (17.71%)
#   Mestizo / ladino: 5263 (7.35%)
#   : 5157 (7.20%)
#   Mestizo, Ladino: 4994 (6.98%)
#   Maya: 4675 (6.53%)
#   Mestizo / Ladino: 4234 (5.92%)
#   Otro: 567 (0.79%)
#
# --- NACIONALIDAD (MUJERES) ---
# Principales nacionalidades:
#   Guatemala: 70123 (97.97%)
#   Estados Unidos de América: 285 (0.40%)
#   Ignorado: 282 (0.39%)
#   El Salvador: 249 (0.35%)
#   Nicaragua: 101 (0.14%)
#
# --- ESCOLARIDAD (MUJERES) ---
# ...

# %% [markdown]
# ## Clustering (agrupamiento no supervisado)

# %%
import numpy as np
import pandas as pd

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

if "df" not in globals():
    raise NameError("No se encuentra el dataframe.")

X = df.copy()

num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = [c for c in X.columns if c not in num_cols]

print("Columnas numéricas:", len(num_cols), num_cols[:10])
print("Columnas categóricas:", len(cat_cols), cat_cols[:10])


num_pipe = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

cat_pipe = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=True))
])

preprocess = ColumnTransformer(
    transformers=[
        ("num", num_pipe, num_cols),
        ("cat", cat_pipe, cat_cols)
    ],
    remainder="drop",
    sparse_threshold=0.3
)

X_feat = preprocess.fit_transform(X)

n_components = 50
svd = TruncatedSVD(n_components=n_components, random_state=42)

X_red = svd.fit_transform(X_feat)
print("Shape luego de preprocess:", getattr(X_feat, "shape", None))
print("Shape luego de SVD:", X_red.shape)

rng = np.random.default_rng(42)
n = X_red.shape[0]
sample_size = min(5000, n)
idx = rng.choice(n, size=sample_size, replace=False)
X_s = X_red[idx]

resultados = []
for k in range(2, 11):
    km = MiniBatchKMeans(n_clusters=k, random_state=42, batch_size=2048, n_init="auto")
    labels_s = km.fit_predict(X_s)
    sil = silhouette_score(X_s, labels_s)
    resultados.append((k, sil))
    print(f"k={k}  silhouette={sil:.4f}")

res_df = pd.DataFrame(resultados, columns=["k", "silhouette"]).sort_values("silhouette", ascending=False)
best_k = int(res_df.iloc[0]["k"])
print("\nMejor k por silhouette (muestra):", best_k)
display(res_df)

final_km = MiniBatchKMeans(n_clusters=best_k, random_state=42, batch_size=2048, n_init="auto")
clusters = final_km.fit_predict(X_red)

df["cluster"] = clusters

print("\nTamaño por cluster:")
display(df["cluster"].value_counts().sort_index().to_frame("conteo"))

if len(num_cols) > 0:
    print("\nPromedios (numéricas) por cluster:")
    display(df.groupby("cluster")[num_cols].mean(numeric_only=True))

top_n = 3
cols_mostrar = cat_cols[:10]  

for col in cols_mostrar:
    print(f"\nTop {top_n} de '{col}' por cluster:")
    tabla = (df.groupby("cluster")[col]
               .apply(lambda s: s.astype(str).value_counts().head(top_n))
               .reset_index(name="conteo"))
    display(tabla)
# Out:
# Columnas numéricas: 6 ['AÑOREG', 'DIAOCU', 'AÑOOCU', 'EDADHOM', 'EDADMUJ', 'DIF_EDAD']
# Columnas categóricas: 22 ['DEPREG', 'MUPREG', 'MESREG', 'MESOCU', 'DEPOCU', 'MUPOCU', 'PUEHOM', 'PUEMUJ', 'NACHOM', 'NACMUJ']
# c:\Users\ninan\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\impute\_base.py:641: UserWarning: Skipping features without any observed values: ['FECHA_OCU']. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# Shape luego de preprocess: (71576, 1266)
# Shape luego de SVD: (71576, 50)
# k=2  silhouette=0.1009
# k=3  silhouette=0.0707
# k=4  silhouette=0.0679
# k=5  silhouette=0.0914
# k=6  silhouette=0.0797
# k=7  silhouette=0.0796
# k=8  silhouette=0.0795
# k=9  silhouette=0.0664
# k=10  silhouette=0.0774
#
# Mejor k por silhouette (muestra): 2
#     k  silhouette
# 0   2    0.100950
# 3   5    0.091394
# 4   6    0.079661
# 5   7    0.079622
# 6   8    0.079479
# 8  10    0.077414
# ...
